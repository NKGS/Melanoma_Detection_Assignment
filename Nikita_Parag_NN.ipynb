# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from google.colab import drive

# %%
## Using the data by mounting the google drive, use the following :
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
root_path = '/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2241
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                               validation_split=0.2,
                                                               subset='training',
                                                               seed=123,
                                                               image_size=(img_height, img_width),
                                                               batch_size=batch_size)
# Out:
# Found 6741 files belonging to 9 classes.
# Using 5393 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                             validation_split=0.2,
                                                             subset="validation",
                                                             seed=123,
                                                             image_size=(img_height, img_width),
                                                             batch_size=batch_size)
# Out:
# Found 6741 files belonging to 9 classes.
# Using 1348 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
### your code goes here, you can use training or validation data to visualize

plt.figure(figsize=(9,9))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax=plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

# %%
input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180,180,3)))
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrap  (None, 178, 178, 32)      896
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 89, 89, 32)        0
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 87, 87, 64)        18496
#  apper)
#
#  module_wrapper_3 (ModuleWr  (None, 43, 43, 64)        0
#  apper)
#
#  module_wrapper_4 (ModuleWr  (None, 41, 41, 128)       73856
#  apper)
#
#  batch_normalization (Batch  (None, 41, 41, 128)       512
#  Normalization)
#
#  module_wrapper_5 (ModuleWr  (None, 20, 20, 128)       0
#  apper)
#
#  module_wrapper_6 (ModuleWr  (None, 51200)             0
#  apper)
#
#  module_wrapper_7 (ModuleWr  (None, 256)               13107456
#  apper)
#
#  module_wrapper_8 (ModuleWr  (None, 256)               0
#  apper)
#
#  module_wrapper_9 (ModuleWr  (None, 256)               0
#  apper)
#
#  module_wrapper_10 (ModuleW  (None, 1)                 257
#  rapper)
#
#  module_wrapper_11 (ModuleW  (None, 1)                 0
#  rapper)
#
# =================================================================
# Total params: 13201473 (50.36 MB)
# Trainable params: 13201217 (50.36 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrap  (None, 178, 178, 32)      896
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 89, 89, 32)        0
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 87, 87, 64)        18496
#  apper)
#
#  module_wrapper_3 (ModuleWr  (None, 43, 43, 64)        0
#  apper)
#
#  module_wrapper_4 (ModuleWr  (None, 41, 41, 128)       73856
#  apper)
#
#  batch_normalization (Batch  (None, 41, 41, 128)       512
#  Normalization)
#
#  module_wrapper_5 (ModuleWr  (None, 20, 20, 128)       0
#  apper)
#
#  module_wrapper_6 (ModuleWr  (None, 51200)             0
#  apper)
#
#  module_wrapper_7 (ModuleWr  (None, 256)               13107456
#  apper)
#
#  module_wrapper_8 (ModuleWr  (None, 256)               0
#  apper)
#
#  module_wrapper_9 (ModuleWr  (None, 256)               0
#  apper)
#
#  module_wrapper_10 (ModuleW  (None, 1)                 257
#  rapper)
#
#  module_wrapper_11 (ModuleW  (None, 1)                 0
#  rapper)
#
# =================================================================
# Total params: 13201473 (50.36 MB)
# Trainable params: 13201217 (50.36 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 394s 4s/step - loss: -16904.4824 - accuracy: 0.1701 - val_loss: -23737.5215 - val_accuracy: 0.1496
# Epoch 2/20
# 57/57 [==============================] - 169s 3s/step - loss: -162593.8750 - accuracy: 0.1723 - val_loss: -26632.8086 - val_accuracy: 0.1496
# Epoch 3/20
# 57/57 [==============================] - 180s 3s/step - loss: -802524.5000 - accuracy: 0.1723 - val_loss: -330669.9375 - val_accuracy: 0.1496
# Epoch 4/20
# 57/57 [==============================] - 159s 3s/step - loss: -2670465.7500 - accuracy: 0.1723 - val_loss: -2232452.5000 - val_accuracy: 0.1496
# Epoch 5/20
# 57/57 [==============================] - 170s 3s/step - loss: -6340828.5000 - accuracy: 0.1723 - val_loss: -5027740.0000 - val_accuracy: 0.1496
# Epoch 6/20
# 57/57 [==============================] - 178s 3s/step - loss: -12008676.0000 - accuracy: 0.1723 - val_loss: -10728202.0000 - val_accuracy: 0.1496
# Epoch 7/20
# 57/57 [==============================] - 165s 3s/step - loss: -20250682.0000 - accuracy: 0.1723 - val_loss: -29854740.0000 - val_accuracy: 0.1496
# Epoch 8/20
# 57/57 [==============================] - 171s 3s/step - loss: -31305196.0000 - accuracy: 0.1723 - val_loss: -32092174.0000 - val_accuracy: 0.1496
# Epoch 9/20
# 57/57 [==============================] - 166s 3s/step - loss: -45579472.0000 - accuracy: 0.1723 - val_loss: -55965984.0000 - val_accuracy: 0.1496
# Epoch 10/20
# 57/57 [==============================] - 165s 3s/step - loss: -63094528.0000 - accuracy: 0.1723 - val_loss: -70115392.0000 - val_accuracy: 0.1496
# Epoch 11/20
# 57/57 [==============================] - 162s 3s/step - loss: -83678552.0000 - accuracy: 0.1723 - val_loss: -109341680.0000 - val_accuracy: 0.1496
# Epoch 12/20
# 57/57 [==============================] - 166s 3s/step - loss: -108819096.0000 - accuracy: 0.1723 - val_loss: -158359168.0000 - val_accuracy: 0.1496
# Epoch 13/20
# 57/57 [==============================] - 161s 3s/step - loss: -138700336.0000 - accuracy: 0.1723 - val_loss: -158843280.0000 - val_accuracy: 0.1496
# Epoch 14/20
# 57/57 [==============================] - 159s 3s/step - loss: -173533600.0000 - accuracy: 0.1723 - val_loss: -208693344.0000 - val_accuracy: 0.1496
# Epoch 15/20
# 57/57 [==============================] - 163s 3s/step - loss: -211096240.0000 - accuracy: 0.1723 - val_loss: -209886976.0000 - val_accuracy: 0.1496
# Epoch 16/20
# 57/57 [==============================] - 164s 3s/step - loss: -254578448.0000 - accuracy: 0.1723 - val_loss: -250073616.0000 - val_accuracy: 0.1496
# Epoch 17/20
# 57/57 [==============================] - 167s 3s/step - loss: -304151584.0000 - accuracy: 0.1723 - val_loss: -330429472.0000 - val_accuracy: 0.1496
# Epoch 18/20
# 57/57 [==============================] - 158s 3s/step - loss: -357827168.0000 - accuracy: 0.1723 - val_loss: -497568160.0000 - val_accuracy: 0.1496
# Epoch 19/20
# 57/57 [==============================] - 157s 3s/step - loss: -416365280.0000 - accuracy: 0.1723 - val_loss: -428656544.0000 - val_accuracy: 0.1496
# Epoch 20/20
# 57/57 [==============================] - 166s 3s/step - loss: -481176288.0000 - accuracy: 0.1723 - val_loss: -535279968.0000 - val_accuracy: 0.1496

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)


# Thus we can clearly that model Overfit and we need to chose right data augumentation strategy
# Out:
# 57/57 [==============================] - 41s 727ms/step - loss: -530378304.0000 - accuracy: 0.1723
# 14/14 [==============================] - 9s 647ms/step - loss: -535279968.0000 - accuracy: 0.1496
# Accuracy:  0.1723368614912033
# Validation Accuracy:  0.1495535671710968
# Loss:  -530378304.0
# Validation Loss -535279968.0

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit
#
# #### Model is overfit and we need to chose right data augmentation strategy

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# # Perform correct augmentation to correct the data

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(180,
                                  180,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
num_classes=len(class_names)
print(num_classes)
# Out:
# 9

# %% [markdown]
# Create model

# %%
input_shape = (180,180,3)
model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=input_shape))
model.add(Conv2D(16, kernel_size=(3,3), padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper_12 (ModuleW  (None, 180, 180, 16)      448
#  rapper)
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  module_wrapper_13 (ModuleW  (None, 90, 90, 32)        4640
#  rapper)
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  module_wrapper_14 (ModuleW  (None, 45, 45, 64)        18496
#  rapper)
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  module_wrapper_15 (ModuleW  (None, 22, 22, 64)        0
#  rapper)
#
#  module_wrapper_16 (ModuleW  (None, 30976)             0
#  rapper)
#
#  module_wrapper_17 (ModuleW  (None, 128)               3965056
#  rapper)
#
#  module_wrapper_18 (ModuleW  (None, 9)                 1161
#  rapper)
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Compile model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Train model

# %%
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=20
)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 71s 1s/step - loss: 1.9473 - accuracy: 0.2571 - val_loss: 1.7940 - val_accuracy: 0.3192
# Epoch 2/20
# 57/57 [==============================] - 73s 1s/step - loss: 1.6943 - accuracy: 0.3726 - val_loss: 1.5231 - val_accuracy: 0.4799
# Epoch 3/20
# 57/57 [==============================] - 68s 1s/step - loss: 1.4779 - accuracy: 0.4925 - val_loss: 1.3830 - val_accuracy: 0.5424
# Epoch 4/20
# 57/57 [==============================] - 74s 1s/step - loss: 1.3582 - accuracy: 0.5086 - val_loss: 1.3844 - val_accuracy: 0.5357
# Epoch 5/20
# 57/57 [==============================] - 68s 1s/step - loss: 1.2245 - accuracy: 0.5678 - val_loss: 1.3978 - val_accuracy: 0.4933
# Epoch 6/20
# 57/57 [==============================] - 70s 1s/step - loss: 1.1486 - accuracy: 0.5845 - val_loss: 1.5554 - val_accuracy: 0.4978
# Epoch 7/20
# 57/57 [==============================] - 72s 1s/step - loss: 1.0759 - accuracy: 0.6185 - val_loss: 1.2665 - val_accuracy: 0.5826
# Epoch 8/20
# 57/57 [==============================] - 70s 1s/step - loss: 1.0143 - accuracy: 0.6397 - val_loss: 1.4179 - val_accuracy: 0.5625
# Epoch 9/20
# 57/57 [==============================] - 71s 1s/step - loss: 0.8785 - accuracy: 0.6877 - val_loss: 1.5269 - val_accuracy: 0.5871
# Epoch 10/20
# 57/57 [==============================] - 76s 1s/step - loss: 0.8213 - accuracy: 0.7078 - val_loss: 1.4662 - val_accuracy: 0.5469
# Epoch 11/20
# 57/57 [==============================] - 72s 1s/step - loss: 0.7322 - accuracy: 0.7434 - val_loss: 1.5305 - val_accuracy: 0.5290
# Epoch 12/20
# 57/57 [==============================] - 66s 1s/step - loss: 0.6179 - accuracy: 0.7892 - val_loss: 1.8464 - val_accuracy: 0.5022
# Epoch 13/20
# 57/57 [==============================] - 76s 1s/step - loss: 0.5583 - accuracy: 0.8120 - val_loss: 1.6604 - val_accuracy: 0.5848
# Epoch 14/20
# 57/57 [==============================] - 75s 1s/step - loss: 0.5198 - accuracy: 0.8076 - val_loss: 1.8768 - val_accuracy: 0.5625
# Epoch 15/20
# 57/57 [==============================] - 72s 1s/step - loss: 0.4565 - accuracy: 0.8377 - val_loss: 2.1020 - val_accuracy: 0.5312
# Epoch 16/20
# 57/57 [==============================] - 69s 1s/step - loss: 0.3939 - accuracy: 0.8489 - val_loss: 2.1791 - val_accuracy: 0.5446
# Epoch 17/20
# 57/57 [==============================] - 71s 1s/step - loss: 0.3850 - accuracy: 0.8516 - val_loss: 1.9081 - val_accuracy: 0.5513
# Epoch 18/20
# 57/57 [==============================] - 76s 1s/step - loss: 0.3321 - accuracy: 0.8806 - val_loss: 1.8209 - val_accuracy: 0.5424
# Epoch 19/20
# 57/57 [==============================] - 71s 1s/step - loss: 0.2853 - accuracy: 0.8862 - val_loss: 1.9973 - val_accuracy: 0.5491
# Epoch 20/20
# 57/57 [==============================] - 70s 1s/step - loss: 0.2356 - accuracy: 0.9063 - val_loss: 2.0725 - val_accuracy: 0.5647

# %% [markdown]
# Evaluate model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs=20
epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 57/57 [==============================] - 20s 346ms/step - loss: 0.1754 - accuracy: 0.9303
# 14/14 [==============================] - 4s 294ms/step - loss: 2.0725 - accuracy: 0.5647
# Accuracy:  0.9302844405174255
# Validation Accuracy:  0.5647321343421936
# Loss:  0.17536605894565582
# Validation Loss 2.0724732875823975

# %% [markdown]
# We see that accuracy has improved , however still some sign of **overfitting**

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
def class_distribution_count(directory):

    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))

    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]

    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")
# Out:
# <Axes: xlabel='No. of Image', ylabel='Class'>

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.4)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
data_dir_train = pathlib.Path(data_dir_train)
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/" +i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BA65545FC40>: 100%|██████████| 500/500 [00:24<00:00, 20.40 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7BA65547B490>: 100%|██████████| 500/500 [00:25<00:00, 19.67 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BA66887FE80>: 100%|██████████| 500/500 [00:26<00:00, 18.93 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7BA6554BF730>: 100%|██████████| 500/500 [01:59<00:00,  4.19 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7BA656E8DC30>: 100%|██████████| 500/500 [01:37<00:00,  5.14 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7BA656D7FEE0>: 100%|██████████| 500/500 [00:25<00:00, 19.46 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7BA656F4A110>: 100%|██████████| 500/500 [00:49<00:00, 10.18 Samples/s]
# Initialised with 182 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7BA6554EC940>: 100%|██████████| 500/500 [00:26<00:00, 18.60 Samples/s]
# Initialised with 140 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7BA65547B100>: 100%|██████████| 500/500 [00:24<00:00, 20.39 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# Label
# melanoma                      500
# actinic keratosis             500
# pigmented benign keratosis    500
# nevus                         500
# squamous cell carcinoma       500
# basal cell carcinoma          500
# seborrheic keratosis          500
# dermatofibroma                500
# vascular lesion               500
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
data_dir_train="/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6741 files belonging to 9 classes.
# Using 5393 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6741 files belonging to 9 classes.
# Using 1348 files for validation.

# %%
num_classes
# Out:
# 9

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
input_shape = (180,180,3)
model = Sequential()

model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=input_shape))

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes))

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrap  (None, 180, 180, 32)      896
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 180, 180, 32)      9248
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 90, 90, 32)        0
#  apper)
#
#  batch_normalization (Batch  (None, 90, 90, 32)        128
#  Normalization)
#
#  module_wrapper_3 (ModuleWr  (None, 90, 90, 32)        0
#  apper)
#
#  module_wrapper_4 (ModuleWr  (None, 90, 90, 64)        18496
#  apper)
#
#  module_wrapper_5 (ModuleWr  (None, 90, 90, 64)        36928
#  apper)
#
#  module_wrapper_6 (ModuleWr  (None, 45, 45, 64)        0
#  apper)
#
#  batch_normalization_1 (Bat  (None, 45, 45, 64)        256
#  chNormalization)
#
#  module_wrapper_7 (ModuleWr  (None, 45, 45, 64)        0
#  apper)
#
#  module_wrapper_8 (ModuleWr  (None, 43, 43, 128)       73856
#  apper)
#
#  batch_normalization_2 (Bat  (None, 43, 43, 128)       512
#  chNormalization)
#
#  module_wrapper_9 (ModuleWr  (None, 21, 21, 128)       0
#  apper)
#
#  module_wrapper_10 (ModuleW  (None, 21, 21, 128)       0
#  rapper)
#
#  module_wrapper_11 (ModuleW  (None, 56448)             0
#  rapper)
#
#  module_wrapper_12 (ModuleW  (None, 128)               7225472
#  rapper)
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  module_wrapper_13 (ModuleW  (None, 128)               0
#  rapper)
#
#  module_wrapper_14 (ModuleW  (None, 9)                 1161
#  rapper)
#
# =================================================================
# Total params: 7367465 (28.10 MB)
# Trainable params: 7366761 (28.10 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %% [markdown]
# #### Train your model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 1038s 6s/step - loss: 1.9832 - accuracy: 0.3306 - val_loss: 17.9792 - val_accuracy: 0.1150
# Epoch 2/30
# 169/169 [==============================] - 44s 253ms/step - loss: 1.6437 - accuracy: 0.4298 - val_loss: 2.7387 - val_accuracy: 0.2033
# Epoch 3/30
# 169/169 [==============================] - 47s 273ms/step - loss: 1.3872 - accuracy: 0.5073 - val_loss: 2.3225 - val_accuracy: 0.3071
# Epoch 4/30
# 169/169 [==============================] - 44s 253ms/step - loss: 1.2052 - accuracy: 0.5598 - val_loss: 1.8641 - val_accuracy: 0.3694
# Epoch 5/30
# 169/169 [==============================] - 44s 253ms/step - loss: 1.1682 - accuracy: 0.5833 - val_loss: 1.2969 - val_accuracy: 0.5334
# Epoch 6/30
# 169/169 [==============================] - 43s 248ms/step - loss: 1.0033 - accuracy: 0.6438 - val_loss: 1.2715 - val_accuracy: 0.5438
# Epoch 7/30
# 169/169 [==============================] - 47s 265ms/step - loss: 0.8990 - accuracy: 0.6794 - val_loss: 1.3180 - val_accuracy: 0.5148
# Epoch 8/30
# 169/169 [==============================] - 44s 251ms/step - loss: 0.8290 - accuracy: 0.7050 - val_loss: 1.6270 - val_accuracy: 0.4377
# Epoch 9/30
# 169/169 [==============================] - 44s 253ms/step - loss: 0.8016 - accuracy: 0.7122 - val_loss: 0.8784 - val_accuracy: 0.6951
# Epoch 10/30
# 169/169 [==============================] - 48s 276ms/step - loss: 0.6913 - accuracy: 0.7591 - val_loss: 0.8662 - val_accuracy: 0.6773
# Epoch 11/30
# 169/169 [==============================] - 44s 253ms/step - loss: 0.6024 - accuracy: 0.7871 - val_loss: 0.6723 - val_accuracy: 0.7537
# Epoch 12/30
# 169/169 [==============================] - 44s 251ms/step - loss: 0.5124 - accuracy: 0.8136 - val_loss: 3.8486 - val_accuracy: 0.3138
# Epoch 13/30
# 169/169 [==============================] - 44s 250ms/step - loss: 0.5281 - accuracy: 0.8040 - val_loss: 1.3270 - val_accuracy: 0.5727
# Epoch 14/30
# 169/169 [==============================] - 43s 250ms/step - loss: 0.4768 - accuracy: 0.8261 - val_loss: 0.6360 - val_accuracy: 0.7656
# Epoch 15/30
# 169/169 [==============================] - 47s 271ms/step - loss: 0.4189 - accuracy: 0.8541 - val_loss: 0.8875 - val_accuracy: 0.7003
# Epoch 16/30
# 169/169 [==============================] - 43s 248ms/step - loss: 0.3975 - accuracy: 0.8552 - val_loss: 1.3446 - val_accuracy: 0.5742
# Epoch 17/30
# 169/169 [==============================] - 43s 246ms/step - loss: 0.4078 - accuracy: 0.8472 - val_loss: 0.6627 - val_accuracy: 0.7678
# Epoch 18/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.3710 - accuracy: 0.8620 - val_loss: 1.1339 - val_accuracy: 0.6402
# Epoch 19/30
# 169/169 [==============================] - 43s 247ms/step - loss: 0.3387 - accuracy: 0.8797 - val_loss: 0.8834 - val_accuracy: 0.6988
# Epoch 20/30
# 169/169 [==============================] - 46s 265ms/step - loss: 0.3422 - accuracy: 0.8761 - val_loss: 0.6200 - val_accuracy: 0.7864
# Epoch 21/30
# 169/169 [==============================] - 44s 252ms/step - loss: 0.2944 - accuracy: 0.8895 - val_loss: 0.5250 - val_accuracy: 0.8093
# Epoch 22/30
# 169/169 [==============================] - 43s 248ms/step - loss: 0.2811 - accuracy: 0.8969 - val_loss: 0.8585 - val_accuracy: 0.7270
# Epoch 23/30
# 169/169 [==============================] - 46s 266ms/step - loss: 0.2642 - accuracy: 0.9019 - val_loss: 0.7935 - val_accuracy: 0.7366
# Epoch 24/30
# 169/169 [==============================] - 44s 252ms/step - loss: 0.2699 - accuracy: 0.9014 - val_loss: 2.8532 - val_accuracy: 0.4013
# Epoch 25/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.2591 - accuracy: 0.9039 - val_loss: 1.2960 - val_accuracy: 0.6291
# Epoch 26/30
# 169/169 [==============================] - 44s 251ms/step - loss: 0.2608 - accuracy: 0.9019 - val_loss: 0.9645 - val_accuracy: 0.7166
# Epoch 27/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.2439 - accuracy: 0.9073 - val_loss: 0.7011 - val_accuracy: 0.7752
# Epoch 28/30
# 169/169 [==============================] - 46s 264ms/step - loss: 0.2325 - accuracy: 0.9065 - val_loss: 0.5452 - val_accuracy: 0.8197
# Epoch 29/30
# 169/169 [==============================] - 43s 248ms/step - loss: 0.2237 - accuracy: 0.9160 - val_loss: 0.8329 - val_accuracy: 0.7366
# Epoch 30/30
# 169/169 [==============================] - 43s 250ms/step - loss: 0.2123 - accuracy: 0.9201 - val_loss: 0.7907 - val_accuracy: 0.7455

# %% [markdown]
# #### Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 169/169 [==============================] - 31s 177ms/step - loss: 0.3070 - accuracy: 0.8834
# 43/43 [==============================] - 8s 135ms/step - loss: 0.7907 - accuracy: 0.7455
# Accuracy:  0.8833673000335693
# Validation Accuracy:  0.7455489635467529
# Loss:  0.30702343583106995
# Validation Loss 0.7907465100288391

# %% [markdown]
# #### Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# #### Class rebalance helped overcome overfitting on training data. We see that now validation accuracy has also improved.
